# %%
import cv2
from ultralytics import YOLO
import time  # Import the time module

# Load the YOLOv8 model
model = YOLO(r'E:\Yolo\runs\detect\Shirts_yolo5\weights\best.pt')  # Use double backslashes or raw string for Windows paths

# Open the camera
cap = cv2.VideoCapture(0)

if not cap.isOpened():
    print("Error: Could not open camera.")
    exit()

# Set camera resolution to a lower value to reduce processing load
cap.set(cv2.CAP_PROP_FRAME_WIDTH, 640)
cap.set(cv2.CAP_PROP_FRAME_HEIGHT, 480)

frame_skip = 2  # Process every 2nd frame to reduce lag
frame_count = 0

while True:
    # Capture frame-by-frame
    ret, frame = cap.read()
    
    if not ret:
        print("Error: Could not read frame.")
        break

    # Skip frames to reduce processing load
    if frame_count % frame_skip == 0:
        start_time = time.time()

        # Predict using YOLOv8
        results = model.predict(frame)

        # Check if results are empty
        if results is None or not results:
            print("No results found.")
        else:
            # Debug: print results
            print(f"Results: {results}")

            # Visualize results
            for result in results:
                boxes = result.boxes.xyxy.numpy()
                confidences = result.boxes.conf.numpy()
                class_ids = result.boxes.cls.numpy()

                # Debug: print box coordinates, confidences, and class IDs
                print(f"Boxes: {boxes}")
                print(f"Confidences: {confidences}")
                print(f"Class IDs: {class_ids}")

                for box, confidence, class_id in zip(boxes, confidences, class_ids):
                    x1, y1, x2, y2 = map(int, box)
                    label = f"{result.names[int(class_id)]}: {confidence:.2f}"

                    # Draw rectangle and label
                    cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)
                    cv2.putText(frame, label, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)

        # Display the frame
        cv2.imshow('YOLOv8 Object Detection', frame)
        
        end_time = time.time()
        print(f"Frame processing time: {end_time - start_time:.2f} seconds")
    
    frame_count += 1

    # Break the loop on 'q' key press
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# When everything is done, release the capture
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 192x256 (no detections), 100.1ms
# Speed: 2.2ms preprocess, 100.1ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 256)
# Results: [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'blue shirt', 1: 'white shirt', 2: 'grey shirt', 3: 'black shirt'}
# obb: None
# orig_img: array([[[197, 199, 195],
#         [193, 195, 190],
#         [191, 193, 189],
#         ...,
#         [139, 137, 111],
#         [139, 138, 109],
#         [135, 133, 104]],
#
#        [[196, 198, 193],
#         [194, 196, 191],
#         [194, 196, 191],
#         ...,
#         [135, 136, 111],
#         [135, 135, 108],
#         [135, 135, 108]],
#
#        [[197, 199, 195],
#         [196, 198, 193],
#         [195, 197, 192],
#         ...,
#         [134, 136, 111],
#         [134, 136, 111],
#         [136, 138, 113]],
#
#        ...,
#
#        [[ 88,  89,  77],
#         [ 88,  90,  78],
#         [ 92,  94,  80],
#         ...,
#         [ 39,  33,  26],
#         [ 52,  47,  45],
#         [ 53,  48,  47]],
#
#        [[ 86,  86,  70],
#         [ 86,  86,  71],
#         [ 90,  89,  76],
#         ...,
#         [ 49,  40,  31],
#         [ 54,  45,  41],
#         [ 59,  49,  46]],
#
#        [[ 88,  87,  69],
#         [ 88,  86,  69],
#         [ 89,  87,  72],
#         ...,
#         [ 81,  67,  51],
#         [ 69,  55,  50],
#         [ 64,  50,  46]]], dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: 'runs\\detect\\predict'
# speed: {'preprocess': 2.1746158599853516, 'inference': 100.1429557800293, 'postprocess': 1.9996166229248047}]
# Boxes: []
# Confidences: []
# Class IDs: []
# Frame processing time: 4.10 seconds
#
# 0: 192x256 (no detections), 85.2ms
# Speed: 8.0ms preprocess, 85.2ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 256)
# Results: [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'blue shirt', 1: 'white shirt', 2: 'grey shirt', 3: 'black shirt'}
# obb: None
# orig_img: array([[[200, 200, 202],
#         [197, 198, 200],
#         [197, 198, 200],
#         ...,
#         [132, 135, 119],
#         [132, 137, 119],
#         [132, 137, 118]],
#
#        [[201, 201, 203],
#         [200, 200, 202],
#         [198, 199, 201],
#         ...,
#         [133, 138, 122],
#         [132, 137, 119],
#         [132, 137, 118]],
#
#        [[202, 202, 205],
#         [201, 201, 203],
#         [200, 200, 202],
#         ...,
#         [133, 138, 121],
#         [132, 137, 119],
#         [131, 136, 117]],
#
#        ...,
#
#        [[ 90,  94,  93],
#         [ 92,  93,  94],
#         [ 95,  93,  93],
#         ...,
#         [147, 156, 143],
#         [146, 155, 143],
#         [144, 152, 140]],
#
#        [[ 88,  89,  89],
#         [ 87,  88,  88],
#         [ 91,  90,  90],
#         ...,
#         [145, 153, 142],
#         [145, 153, 143],
#         [143, 151, 141]],
#
#        [[ 85,  86,  86],
#         [ 87,  86,  86],
#         [ 92,  88,  89],
#         ...,
#         [146, 154, 145],
#         [145, 153, 143],
#         [144, 152, 142]]], dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: 'runs\\detect\\predict'
# speed: {'preprocess': 7.99560546875, 'inference': 85.19911766052246, 'postprocess': 0.9996891021728516}]
# Boxes: []
# Confidences: []
# Class IDs: []
# Frame processing time: 0.10 seconds
#
# 0: 192x256 (no detections), 87.0ms
# Speed: 4.4ms preprocess, 87.0ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 256)
# Results: [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'blue shirt', 1: 'white shirt', 2: 'grey shirt', 3: 'black shirt'}
# obb: None
# orig_img: array([[[201, 201, 203],
#         [197, 198, 199],
#         [197, 198, 198],
#         ...,
#         [130, 137, 120],
#         [130, 135, 115],
#         [130, 136, 114]],
#
#        [[204, 205, 207],
#         [198, 199, 201],
#         [197, 198, 200],
#         ...,
#         [132, 138, 121],
#         [131, 136, 118],
#         [131, 136, 117]],
#
#        [[204, 205, 207],
#         [202, 202, 205],
#         [200, 200, 202],
#         ...,
#         [133, 139, 123],
#         [132, 137, 119],
#         [131, 136, 117]],
#
#        ...,
#
#        [[121, 101,  85],
#         [122, 103,  89],
#         [122, 105,  93],
#         ...,
#         [150, 156, 142],
#         [150, 156, 142],
#         [147, 154, 140]],
#
#        [[135, 113,  97],
#         [132, 110,  95],
#         [127, 106,  93],
#         ...,
#         [149, 155, 141],
#         [147, 154, 140],
#         [144, 150, 136]],
#
#        [[145, 118, 102],
#         [148, 123, 108],
#         [122,  99,  86],
#         ...,
#         [149, 155, 141],
#         [146, 153, 139],
#         [143, 149, 135]]], dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: 'runs\\detect\\predict'
# speed: {'preprocess': 4.355669021606445, 'inference': 86.98558807373047, 'postprocess': 0.9984970092773438}]
# Boxes: []
# Confidences: []
# Class IDs: []
# Frame processing time: 0.10 seconds
#
# 0: 192x256 (no detections), 76.4ms
# Speed: 4.0ms preprocess, 76.4ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 256)
# Results: [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'blue shirt', 1: 'white shirt', 2: 'grey shirt', 3: 'black shirt'}
# obb: None
# orig_img: array([[[196, 199, 201],
#         [198, 198, 198],
#         [201, 198, 196],
#         ...,
#         [134, 139, 123],
#         [134, 139, 123],
#         [134, 139, 123]],
#
#        [[199, 201, 203],
#         [197, 199, 200],
#         [197, 198, 198],
#         ...,
#         [134, 139, 123],
#         [134, 139, 123],
#         [134, 139, 123]],
#
#        [[200, 203, 205],
#         [198, 200, 202],
#         [197, 198, 200],
#         ...,
#         [133, 137, 123],
#         [133, 137, 123],
#         [133, 137, 123]],
#
#        ...,
#
#        [[179, 158, 137],
#         [178, 158, 138],
#         [178, 159, 140],
#         ...,
#         [149, 158, 143],
#         [148, 156, 142],
#         [148, 156, 142]],
#
#        [[178, 159, 138],
#         [180, 159, 139],
#         [182, 160, 141],
#         ...,
#         [149, 155, 141],
#         [149, 155, 141],
#         [146, 153, 139]],
#
#        [[177, 159, 135],
#         [180, 159, 137],
#         [183, 161, 141],
#         ...,
#         [149, 155, 141],
#         [146, 153, 139],
#         [144, 150, 136]]], dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: 'runs\\detect\\predict'
# speed: {'preprocess': 3.9997100830078125, 'inference': 76.44796371459961, 'postprocess': 0.9982585906982422}]
# Boxes: []
# Confidences: []
# Class IDs: []
# Frame processing time: 0.09 seconds
#
# 0: 192x256 (no detections), 79.0ms
# Speed: 3.0ms preprocess, 79.0ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 256)
# Results: [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'blue shirt', 1: 'white shirt', 2: 'grey shirt', 3: 'black shirt'}
# obb: None
# orig_img: array([[[207, 198, 199],
#         [203, 195, 196],
#         [202, 194, 195],
#         ...,
#         [133, 136, 129],
#         [133, 136, 127],
#         [131, 134, 124]],
#
#        [[205, 198, 201],
#         [203, 197, 199],
#         [202, 196, 197],
#         ...,
#         [133, 136, 128],
#         [132, 135, 126],
#         [131, 134, 125]],
#
#        [[206, 202, 205],
#         [203, 198, 201],
#         [200, 196, 199],
#         ...,
#         [134, 138, 127],
#         [132, 136, 124],
#         [131, 135, 123]],
#
#        ...,
#
#        [[140, 115,  99],
#         [144, 118, 102],
#         [133, 108,  92],
#         ...,
#         [147, 157, 147],
#         [145, 156, 146],
#         [147, 157, 147]],
#
#        [[159, 135, 117],
#         [164, 140, 121],
#         [151, 127, 109],
#         ...,
#         [145, 156, 146],
#         [144, 154, 144],
#         [143, 153, 143]],
#
#        [[158, 134, 114],
#         [159, 135, 116],
#         [164, 142, 124],
#         ...,
#         [145, 156, 146],
#         [144, 154, 144],
#         [138, 149, 139]]], dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: 'runs\\detect\\predict'
# speed: {'preprocess': 2.9990673065185547, 'inference': 78.95398139953613, 'postprocess': 0.9996891021728516}]
# Boxes: []
# Confidences: []
# Class IDs: []
# Frame processing time: 0.09 seconds
#
# 0: 192x256 (no detections), 79.1ms
# Speed: 2.0ms preprocess, 79.1ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 256)
# Results: [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'blue shirt', 1: 'white shirt', 2: 'grey shirt', 3: 'black shirt'}
# obb: None
# orig_img: array([[[197, 195, 198],
#         [197, 195, 199],
#         [196, 193, 198],
#         ...,
#         [127, 131, 118],
#         [127, 132, 118],
#         [127, 132, 117]],
#
#        [[200, 198, 203],
#         [198, 196, 201],
#         [197, 195, 199],
#         ...,
#         [127, 132, 121],
#         [128, 134, 122],
#         [129, 135, 123]],
#
#        [[202, 199, 206],
#         [198, 197, 203],
#         [197, 197, 202],
#         ...,
#         [130, 135, 123],
#         [132, 138, 126],
#         [131, 137, 125]],
#
#        ...,
#
#        [[ 91,  87,  89],
#         [ 87,  82,  84],
#         [ 94,  88,  89],
#         ...,
#         [141, 152, 137],
#         [140, 151, 136],
#         [143, 154, 140]],
#
#        [[ 90,  86,  86],
#         [ 88,  85,  85],
#         [ 90,  86,  86],
#         ...,
#         [138, 150, 135],
#         [137, 148, 134],
#         [137, 148, 134]],
#
#        [[ 90,  86,  86],
#         [ 92,  88,  89],
#         [ 92,  88,  89],
#         ...,
#         [142, 152, 137],
#         [138, 148, 131],
#         [134, 143, 126]]], dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: 'runs\\detect\\predict'
# speed: {'preprocess': 1.9998550415039062, 'inference': 79.07819747924805, 'postprocess': 0.0}]
# Boxes: []
# Confidences: []
# Class IDs: []
# Frame processing time: 0.09 seconds
#
# 0: 192x256 (no detections), 100.1ms
# Speed: 3.0ms preprocess, 100.1ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 256)
# Results: [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'blue shirt', 1: 'white shirt', 2: 'grey shirt', 3: 'black shirt'}
# obb: None
# orig_img: array([[[193, 194, 192],
#         [190, 192, 189],
#         [190, 192, 189],
#         ...,
#         [126, 128, 119],
#         [125, 126, 117],
#         [127, 128, 119]],
#
#        [[190, 192, 189],
#         [190, 191, 190],
#         [189, 190, 190],
#         ...,
#         [126, 127, 116],
#         [124, 125, 114],
#         [126, 127, 116]],
#
#        [[188, 189, 189],
#         [189, 190, 190],
#         [189, 190, 190],
#         ...,
#         [125, 127, 116],
#         [121, 123, 111],
#         [124, 125, 114]],
#
#        ...,
#
#        [[ 87,  88,  86],
#         [ 88,  89,  87],
#         [ 90,  92,  89],
#         ...,
#         [140, 151, 136],
#         [137, 148, 134],
#         [135, 146, 132]],
#
#        [[ 85,  87,  85],
#         [ 89,  91,  87],
#         [ 90,  92,  88],
#         ...,
#         [139, 149, 133],
#         [138, 147, 133],
#         [137, 146, 132]],
#
#        [[ 80,  82,  77],
#         [ 78,  81,  76],
#         [ 83,  85,  81],
#         ...,
#         [138, 147, 132],
#         [138, 147, 133],
#         [138, 147, 133]]], dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: 'runs\\detect\\predict'
# speed: {'preprocess': 2.999544143676758, 'inference': 100.10981559753418, 'postprocess': 1.0001659393310547}]
# Boxes: []
# Confidences: []
# Class IDs: []
# Frame processing time: 0.11 seconds
#
# 0: 192x256 (no detections), 85.0ms
# Speed: 2.0ms preprocess, 85.0ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 256)
# Results: [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'blue shirt', 1: 'white shirt', 2: 'grey shirt', 3: 'black shirt'}
# obb: None
# orig_img: array([[[192, 190, 195],
#         [192, 189, 194],
#         [193, 189, 194],
#         ...,
#         [117, 132, 126],
#         [116, 129, 124],
#         [114, 128, 122]],
#
#        [[194, 194, 198],
#         [191, 190, 195],
#         [191, 189, 194],
#         ...,
#         [119, 131, 123],
#         [119, 131, 123],
#         [119, 131, 123]],
#
#        [[198, 198, 205],
#         [193, 192, 199],
#         [190, 190, 197],
#         ...,
#         [119, 130, 125],
#         [118, 129, 124],
#         [119, 130, 125]],
#
#        ...,
#
#        [[ 88,  82,  83],
#         [ 90,  83,  84],
#         [ 91,  85,  85],
#         ...,
#         [136, 145, 130],
#         [136, 145, 130],
#         [137, 146, 132]],
#
#        [[ 88,  80,  81],
#         [ 91,  82,  83],
#         [ 92,  83,  84],
#         ...,
#         [135, 143, 130],
#         [134, 142, 128],
#         [132, 141, 127]],
#
#        [[ 91,  81,  82],
#         [ 92,  82,  83],
#         [ 92,  83,  84],
#         ...,
#         [130, 138, 126],
#         [131, 140, 128],
#         [130, 138, 126]]], dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: 'runs\\detect\\predict'
# speed: {'preprocess': 1.9996166229248047, 'inference': 84.95187759399414, 'postprocess': 1.0004043579101562}]
# Boxes: []
# Confidences: []
# Class IDs: []
# Frame processing time: 0.10 seconds
#
# 0: 192x256 (no detections), 80.4ms
# Speed: 7.0ms preprocess, 80.4ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 256)
# Results: [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'blue shirt', 1: 'white shirt', 2: 'grey shirt', 3: 'black shirt'}
# obb: None
# orig_img: array([[[193, 190, 190],
#         [197, 193, 193],
#         [194, 191, 191],
#         ...,
#         [126, 129, 114],
#         [127, 130, 113],
#         [130, 132, 116]],
#
#        [[196, 192, 192],
#         [197, 194, 195],
#         [195, 193, 194],
#         ...,
#         [124, 128, 113],
#         [125, 130, 113],
#         [126, 131, 115]],
#
#        [[197, 195, 198],
#         [196, 195, 198],
#         [195, 195, 198],
#         ...,
#         [126, 131, 115],
#         [126, 131, 115],
#         [126, 131, 115]],
#
#        ...,
#
#        [[ 87,  81,  82],
#         [ 89,  83,  84],
#         [ 91,  85,  85],
#         ...,
#         [138, 150, 135],
#         [135, 149, 134],
#         [134, 148, 133]],
#
#        [[ 85,  81,  82],
#         [ 88,  84,  84],
#         [ 89,  83,  84],
#         ...,
#         [137, 147, 133],
#         [135, 146, 132],
#         [131, 143, 128]],
#
#        [[ 86,  83,  83],
#         [ 87,  82,  83],
#         [ 88,  82,  83],
#         ...,
#         [139, 148, 134],
#         [135, 146, 132],
#         [132, 144, 129]]], dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: 'runs\\detect\\predict'
# speed: {'preprocess': 6.996631622314453, 'inference': 80.44266700744629, 'postprocess': 0.9996891021728516}]
# Boxes: []
# Confidences: []
# Class IDs: []
# Frame processing time: 0.10 seconds
#
# 0: 192x256 (no detections), 87.8ms
# Speed: 3.0ms preprocess, 87.8ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 256)
# Results: [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'blue shirt', 1: 'white shirt', 2: 'grey shirt', 3: 'black shirt'}
# obb: None
# orig_img: array([[[193, 192, 199],
#         [190, 190, 197],
#         [190, 190, 197],
#         ...,
#         [133, 131, 122],
#         [132, 130, 121],
#         [133, 131, 122]],
#
#        [[196, 196, 201],
#         [197, 197, 202],
#         [191, 191, 196],
#         ...,
#         [128, 130, 118],
#         [131, 132, 121],
#         [132, 133, 122]],
#
#        [[200, 199, 204],
#         [196, 197, 202],
#         [192, 194, 198],
#         ...,
#         [128, 130, 117],
#         [129, 131, 119],
#         [131, 132, 121]],
#
#        ...,
#
#        [[ 83,  84,  84],
#         [ 85,  85,  85],
#         [ 89,  87,  88],
#         ...,
#         [144, 150, 136],
#         [143, 149, 135],
#         [139, 146, 132]],
#
#        [[ 81,  84,  84],
#         [ 82,  84,  84],
#         [ 85,  86,  86],
#         ...,
#         [142, 151, 135],
#         [141, 150, 133],
#         [131, 141, 124]],
#
#        [[ 78,  81,  79],
#         [ 78,  81,  80],
#         [ 83,  84,  84],
#         ...,
#         [141, 149, 136],
#         [141, 149, 135],
#         [130, 139, 124]]], dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: 'runs\\detect\\predict'
# speed: {'preprocess': 3.0007362365722656, 'inference': 87.8305435180664, 'postprocess': 0.9984970092773438}]
# Boxes: []
# Confidences: []
# Class IDs: []
# Frame processing time: 0.10 seconds
#
# 0: 192x256 (no detections), 75.0ms
# Speed: 2.0ms preprocess, 75.0ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 256)
# Results: [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'blue shirt', 1: 'white shirt', 2: 'grey shirt', 3: 'black shirt'}
# obb: None
# orig_img: array([[[196, 196, 199],
#         [194, 194, 197],
#         [193, 192, 197],
#         ...,
#         [129, 129, 120],
#         [128, 124, 115],
#         [126, 122, 113]],
#
#        [[196, 196, 201],
#         [195, 195, 199],
#         [191, 191, 196],
#         ...,
#         [128, 128, 119],
#         [127, 125, 117],
#         [127, 125, 117]],
#
#        [[194, 196, 201],
#         [192, 194, 198],
#         [190, 193, 197],
#         ...,
#         [127, 128, 119],
#         [127, 128, 119],
#         [128, 129, 120]],
#
#        ...,
#
#        [[ 81,  82,  82],
#         [ 82,  82,  81],
#         [ 96,  95,  93],
#         ...,
#         [135, 145, 130],
#         [133, 144, 129],
#         [133, 144, 129]],
#
#        [[ 82,  81,  79],
#         [ 84,  82,  80],
#         [ 90,  87,  85],
#         ...,
#         [133, 147, 131],
#         [130, 145, 130],
#         [128, 144, 129]],
#
#        [[ 81,  79,  79],
#         [ 83,  81,  80],
#         [ 86,  83,  81],
#         ...,
#         [133, 149, 134],
#         [129, 147, 132],
#         [124, 142, 127]]], dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: 'runs\\detect\\predict'
# speed: {'preprocess': 1.9993782043457031, 'inference': 74.99551773071289, 'postprocess': 0.9989738464355469}]
# Boxes: []
# Confidences: []
# Class IDs: []
# Frame processing time: 0.09 seconds
#
# 0: 192x256 (no detections), 63.7ms
# Speed: 1.0ms preprocess, 63.7ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 256)
# Results: [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'blue shirt', 1: 'white shirt', 2: 'grey shirt', 3: 'black shirt'}
# obb: None
# orig_img: array([[[190, 191, 191],
#         [192, 194, 193],
#         [193, 194, 194],
#         ...,
#         [133, 129, 120],
#         [131, 127, 119],
#         [131, 127, 119]],
#
#        [[193, 194, 194],
#         [192, 194, 193],
#         [193, 194, 194],
#         ...,
#         [133, 129, 119],
#         [130, 126, 118],
#         [130, 126, 118]],
#
#        [[195, 196, 196],
#         [192, 194, 193],
#         [191, 192, 192],
#         ...,
#         [127, 129, 116],
#         [126, 127, 116],
#         [126, 127, 116]],
#
#        ...,
#
#        [[ 85,  85,  90],
#         [ 85,  85,  90],
#         [ 88,  88,  92],
#         ...,
#         [138, 147, 135],
#         [139, 148, 136],
#         [136, 144, 132]],
#
#        [[ 84,  85,  87],
#         [ 85,  86,  88],
#         [ 87,  87,  89],
#         ...,
#         [141, 149, 137],
#         [138, 147, 135],
#         [135, 143, 131]],
#
#        [[ 80,  81,  81],
#         [ 83,  84,  85],
#         [ 84,  85,  87],
#         ...,
#         [142, 150, 137],
#         [138, 147, 135],
#         [134, 142, 130]]], dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: 'runs\\detect\\predict'
# speed: {'preprocess': 1.0004043579101562, 'inference': 63.65156173706055, 'postprocess': 0.9984970092773438}]
# Boxes: []
# Confidences: []
# Class IDs: []
# Frame processing time: 0.08 seconds
#
# 0: 192x256 (no detections), 63.1ms
# Speed: 2.0ms preprocess, 63.1ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 256)
# Results: [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'blue shirt', 1: 'white shirt', 2: 'grey shirt', 3: 'black shirt'}
# obb: None
# orig_img: array([[[196, 195, 204],
#         [190, 189, 198],
#         [190, 189, 198],
#         ...,
#         [133, 132, 116],
#         [133, 131, 113],
#         [131, 130, 111]],
#
#        [[196, 195, 202],
#         [190, 190, 196],
#         [190, 190, 197],
#         ...,
#         [130, 130, 115],
#         [130, 130, 115],
#         [131, 130, 115]],
#
#        [[196, 195, 202],
#         [196, 197, 203],
#         [193, 194, 201],
#         ...,
#         [127, 131, 115],
#         [129, 132, 116],
#         [130, 132, 116]],
#
#        ...,
#
#        [[ 87,  87,  89],
#         [ 86,  87,  89],
#         [ 88,  88,  91],
#         ...,
#         [137, 145, 133],
#         [132, 141, 129],
#         [136, 144, 132]],
#
#        [[ 83,  84,  86],
#         [ 83,  84,  86],
#         [ 84,  85,  87],
#         ...,
#         [136, 144, 133],
#         [134, 141, 132],
#         [134, 141, 132]],
#
#        [[ 83,  84,  86],
#         [ 84,  84,  85],
#         [ 85,  84,  84],
#         ...,
#         [135, 144, 133],
#         [133, 143, 133],
#         [131, 142, 132]]], dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: 'runs\\detect\\predict'
# speed: {'preprocess': 1.9984245300292969, 'inference': 63.14849853515625, 'postprocess': 0.0}]
# Boxes: []
# Confidences: []
# Class IDs: []
# Frame processing time: 0.08 seconds
#
# 0: 192x256 (no detections), 64.0ms
# Speed: 2.0ms preprocess, 64.0ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 256)
# Results: [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'blue shirt', 1: 'white shirt', 2: 'grey shirt', 3: 'black shirt'}
# obb: None
# orig_img: array([[[197, 191, 191],
#         [198, 192, 192],
#         [198, 192, 192],
#         ...,
#         [128, 134, 114],
#         [126, 131, 113],
#         [123, 128, 110]],
#
#        [[197, 193, 195],
#         [196, 193, 194],
#         [195, 193, 194],
#         ...,
#         [126, 132, 112],
#         [126, 131, 113],
#         [124, 129, 111]],
#
#        [[197, 195, 198],
#         [196, 195, 198],
#         [194, 194, 196],
#         ...,
#         [127, 132, 115],
#         [126, 131, 115],
#         [125, 130, 114]],
#
#        ...,
#
#        [[ 91,  87,  88],
#         [ 91,  87,  88],
#         [ 92,  88,  91],
#         ...,
#         [135, 142, 129],
#         [135, 143, 131],
#         [132, 141, 129]],
#
#        [[ 88,  85,  85],
#         [ 87,  84,  84],
#         [ 88,  85,  85],
#         ...,
#         [137, 145, 133],
#         [133, 143, 131],
#         [127, 137, 125]],
#
#        [[ 86,  82,  85],
#         [ 85,  81,  84],
#         [ 86,  82,  85],
#         ...,
#         [141, 150, 137],
#         [133, 146, 132],
#         [131, 145, 130]]], dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: 'runs\\detect\\predict'
# speed: {'preprocess': 1.9996166229248047, 'inference': 63.96222114562988, 'postprocess': 1.0001659393310547}]
# Boxes: []
# Confidences: []
# Class IDs: []
# Frame processing time: 0.08 seconds
#
# 0: 192x256 (no detections), 64.0ms
# Speed: 2.0ms preprocess, 64.0ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 256)
# Results: [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'blue shirt', 1: 'white shirt', 2: 'grey shirt', 3: 'black shirt'}
# obb: None
# orig_img: array([[[194, 196, 191],
#         [193, 195, 190],
#         [191, 193, 189],
#         ...,
#         [127, 132, 118],
#         [127, 132, 118],
#         [127, 132, 118]],
#
#        [[194, 195, 193],
#         [193, 194, 192],
#         [191, 193, 191],
#         ...,
#         [127, 131, 118],
#         [129, 132, 121],
#         [127, 131, 120]],
#
#        [[195, 196, 196],
#         [194, 195, 194],
#         [193, 194, 194],
#         ...,
#         [126, 133, 120],
#         [128, 134, 122],
#         [125, 131, 120]],
#
#        ...,
#
#        [[ 84,  87,  89],
#         [ 84,  87,  89],
#         [ 88,  91,  93],
#         ...,
#         [141, 149, 136],
#         [139, 148, 136],
#         [132, 141, 129]],
#
#        [[ 84,  85,  85],
#         [ 84,  85,  85],
#         [ 85,  86,  86],
#         ...,
#         [138, 147, 134],
#         [135, 143, 131],
#         [130, 138, 126]],
#
#        [[ 83,  84,  84],
#         [ 83,  84,  84],
#         [ 82,  83,  83],
#         ...,
#         [138, 147, 135],
#         [130, 138, 126],
#         [129, 137, 125]]], dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: 'runs\\detect\\predict'
# speed: {'preprocess': 1.9981861114501953, 'inference': 63.96484375, 'postprocess': 0.0}]
# Boxes: []
# Confidences: []
# Class IDs: []
# Frame processing time: 0.07 seconds
#
# 0: 192x256 (no detections), 165.6ms
# Speed: 2.0ms preprocess, 165.6ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 256)
# Results: [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'blue shirt', 1: 'white shirt', 2: 'grey shirt', 3: 'black shirt'}
# obb: None
# orig_img: array([[[194, 196, 202],
#         [190, 192, 198],
#         [192, 194, 198],
#         ...,
#         [125, 129, 121],
#         [124, 130, 120],
#         [124, 130, 120]],
#
#        [[195, 197, 204],
#         [190, 192, 198],
#         [192, 194, 198],
#         ...,
#         [127, 132, 122],
#         [125, 131, 119],
#         [125, 131, 119]],
#
#        [[193, 195, 199],
#         [192, 194, 198],
#         [192, 194, 198],
#         ...,
#         [128, 133, 124],
#         [125, 128, 119],
#         [127, 130, 121]],
#
#        ...,
#
#        [[ 83,  84,  86],
#         [ 85,  85,  87],
#         [ 89,  87,  89],
#         ...,
#         [144, 152, 137],
#         [137, 146, 132],
#         [135, 144, 129]],
#
#        [[ 82,  82,  85],
#         [ 83,  84,  86],
#         [ 84,  85,  87],
#         ...,
#         [140, 147, 133],
#         [139, 146, 132],
#         [138, 145, 130]],
#
#        [[ 81,  81,  85],
#         [ 80,  81,  85],
#         [ 81,  81,  84],
#         ...,
#         [138, 146, 132],
#         [137, 146, 132],
#         [137, 146, 132]]], dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: 'runs\\detect\\predict'
# speed: {'preprocess': 2.020120620727539, 'inference': 165.60053825378418, 'postprocess': 0.9992122650146484}]
# Boxes: []
# Confidences: []
# Class IDs: []
# Frame processing time: 0.18 seconds
#
# 0: 192x256 (no detections), 77.0ms
# Speed: 1.0ms preprocess, 77.0ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 256)
# Results: [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'blue shirt', 1: 'white shirt', 2: 'grey shirt', 3: 'black shirt'}
# obb: None
# orig_img: array([[[190, 192, 199],
#         [190, 192, 199],
#         [189, 191, 198],
#         ...,
#         [123, 128, 125],
#         [125, 127, 124],
#         [125, 126, 124]],
#
#        [[192, 193, 200],
#         [191, 194, 199],
#         [190, 193, 197],
#         ...,
#         [124, 128, 124],
#         [126, 128, 124],
#         [128, 129, 125]],
#
#        [[195, 197, 202],
#         [194, 195, 199],
#         [193, 192, 197],
#         ...,
#         [124, 128, 124],
#         [124, 128, 124],
#         [125, 130, 125]],
#
#        ...,
#
#        [[ 89,  87,  88],
#         [ 90,  89,  89],
#         [ 90,  89,  89],
#         ...,
#         [133, 145, 130],
#         [135, 146, 132],
#         [135, 146, 132]],
#
#        [[ 85,  84,  84],
#         [ 86,  85,  85],
#         [ 89,  87,  88],
#         ...,
#         [134, 145, 131],
#         [134, 145, 130],
#         [131, 143, 128]],
#
#        [[ 85,  81,  82],
#         [ 87,  84,  84],
#         [ 90,  86,  86],
#         ...,
#         [137, 146, 132],
#         [137, 146, 132],
#         [127, 135, 121]]], dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: 'runs\\detect\\predict'
# speed: {'preprocess': 0.9992122650146484, 'inference': 76.95603370666504, 'postprocess': 0.9992122650146484}]
# Boxes: []
# Confidences: []
# Class IDs: []
# Frame processing time: 0.09 seconds
#
# 0: 192x256 (no detections), 62.8ms
# Speed: 2.0ms preprocess, 62.8ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 256)
# Results: [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'blue shirt', 1: 'white shirt', 2: 'grey shirt', 3: 'black shirt'}
# obb: None
# orig_img: array([[[198, 198, 203],
#         [195, 194, 197],
#         [195, 193, 195],
#         ...,
#         [115, 122, 110],
#         [125, 129, 115],
#         [127, 130, 116]],
#
#        [[198, 198, 205],
#         [194, 192, 197],
#         [192, 190, 193],
#         ...,
#         [123, 131, 120],
#         [125, 131, 119],
#         [124, 130, 118]],
#
#        [[197, 197, 202],
#         [191, 190, 195],
#         [192, 190, 195],
#         ...,
#         [125, 132, 121],
#         [126, 132, 121],
#         [125, 131, 119]],
#
#        ...,
#
#        [[ 91,  89,  82],
#         [ 91,  89,  81],
#         [ 92,  90,  82],
#         ...,
#         [143, 148, 134],
#         [140, 147, 133],
#         [138, 145, 130]],
#
#        [[ 88,  86,  82],
#         [ 88,  86,  82],
#         [ 91,  88,  84],
#         ...,
#         [140, 145, 133],
#         [138, 144, 132],
#         [136, 142, 130]],
#
#        [[ 86,  83,  83],
#         [ 87,  84,  83],
#         [ 90,  87,  85],
#         ...,
#         [140, 145, 134],
#         [138, 143, 134],
#         [137, 142, 133]]], dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: 'runs\\detect\\predict'
# speed: {'preprocess': 2.0003318786621094, 'inference': 62.821388244628906, 'postprocess': 0.9992122650146484}]
# Boxes: []
# Confidences: []
# Class IDs: []
# Frame processing time: 0.07 seconds
#
# 0: 192x256 (no detections), 67.0ms
# Speed: 1.8ms preprocess, 67.0ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 256)
# Results: [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'blue shirt', 1: 'white shirt', 2: 'grey shirt', 3: 'black shirt'}
# obb: None
# orig_img: array([[[194, 198, 205],
#         [193, 196, 203],
#         [189, 191, 198],
#         ...,
#         [126, 129, 121],
#         [126, 129, 120],
#         [127, 130, 121]],
#
#        [[193, 197, 204],
#         [188, 191, 198],
#         [189, 191, 198],
#         ...,
#         [127, 130, 122],
#         [127, 130, 121],
#         [127, 130, 121]],
#
#        [[195, 197, 204],
#         [193, 194, 201],
#         [190, 192, 199],
#         ...,
#         [129, 132, 121],
#         [129, 132, 122],
#         [126, 129, 120]],
#
#        ...,
#
#        [[ 85,  83,  86],
#         [ 86,  85,  87],
#         [ 89,  87,  89],
#         ...,
#         [139, 145, 133],
#         [129, 135, 123],
#         [131, 137, 125]],
#
#        [[ 83,  81,  84],
#         [ 83,  81,  84],
#         [ 83,  81,  84],
#         ...,
#         [144, 148, 139],
#         [129, 132, 122],
#         [132, 135, 126]],
#
#        [[ 83,  82,  82],
#         [ 81,  79,  79],
#         [ 78,  74,  75],
#         ...,
#         [141, 145, 138],
#         [134, 137, 130],
#         [133, 136, 129]]], dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: 'runs\\detect\\predict'
# speed: {'preprocess': 1.8308162689208984, 'inference': 66.95818901062012, 'postprocess': 0.9996891021728516}]
# Boxes: []
# Confidences: []
# Class IDs: []
# Frame processing time: 0.08 seconds
#
# 0: 192x256 (no detections), 62.0ms
# Speed: 2.0ms preprocess, 62.0ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 256)
# Results: [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'blue shirt', 1: 'white shirt', 2: 'grey shirt', 3: 'black shirt'}
# obb: None
# orig_img: array([[[196, 193, 198],
#         [193, 190, 195],
#         [193, 189, 194],
#         ...,
#         [126, 129, 120],
#         [126, 129, 120],
#         [129, 132, 122]],
#
#        [[197, 195, 199],
#         [196, 192, 197],
#         [194, 190, 195],
#         ...,
#         [126, 130, 118],
#         [126, 130, 118],
#         [127, 131, 119]],
#
#        [[195, 195, 199],
#         [196, 195, 199],
#         [195, 192, 197],
#         ...,
#         [127, 131, 119],
#         [127, 131, 119],
#         [126, 130, 118]],
#
#        ...,
#
#        [[ 83,  85,  81],
#         [ 85,  87,  84],
#         [ 87,  88,  86],
#         ...,
#         [141, 147, 132],
#         [140, 144, 130],
#         [139, 143, 129]],
#
#        [[ 81,  83,  78],
#         [ 83,  85,  81],
#         [ 85,  87,  85],
#         ...,
#         [137, 144, 128],
#         [136, 142, 128],
#         [135, 141, 127]],
#
#        [[ 84,  83,  81],
#         [ 86,  86,  82],
#         [ 89,  88,  84],
#         ...,
#         [142, 150, 134],
#         [137, 143, 129],
#         [135, 141, 127]]], dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: 'runs\\detect\\predict'
# speed: {'preprocess': 2.000570297241211, 'inference': 61.96427345275879, 'postprocess': 0.9989738464355469}]
# Boxes: []
# Confidences: []
# Class IDs: []
# Frame processing time: 0.07 seconds
#
# 0: 192x256 (no detections), 68.0ms
# Speed: 2.0ms preprocess, 68.0ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 256)
# Results: [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'blue shirt', 1: 'white shirt', 2: 'grey shirt', 3: 'black shirt'}
# obb: None
# orig_img: array([[[197, 198, 200],
#         [195, 195, 199],
#         [193, 192, 197],
#         ...,
#         [122, 127, 107],
#         [122, 127, 106],
#         [122, 127, 106]],
#
#        [[198, 199, 201],
#         [196, 196, 199],
#         [196, 196, 199],
#         ...,
#         [124, 129, 112],
#         [123, 127, 111],
#         [125, 130, 113]],
#
#        [[197, 198, 200],
#         [197, 198, 200],
#         [196, 196, 199],
#         ...,
#         [126, 130, 116],
#         [124, 128, 114],
#         [125, 129, 115]],
#
#        ...,
#
#        [[ 84,  88,  88],
#         [ 83,  85,  85],
#         [ 85,  86,  86],
#         ...,
#         [137, 147, 135],
#         [134, 144, 132],
#         [133, 143, 131]],
#
#        [[ 83,  84,  86],
#         [ 75,  74,  77],
#         [ 84,  82,  85],
#         ...,
#         [136, 147, 135],
#         [133, 143, 131],
#         [131, 142, 130]],
#
#        [[ 81,  81,  85],
#         [ 81,  80,  83],
#         [ 82,  80,  82],
#         ...,
#         [136, 147, 135],
#         [134, 144, 132],
#         [133, 143, 131]]], dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: 'runs\\detect\\predict'
# speed: {'preprocess': 2.0020008087158203, 'inference': 67.95883178710938, 'postprocess': 0.9982585906982422}]
# Boxes: []
# Confidences: []
# Class IDs: []
# Frame processing time: 0.08 seconds
#
# 0: 192x256 (no detections), 73.0ms
# Speed: 2.0ms preprocess, 73.0ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 256)
# Results: [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'blue shirt', 1: 'white shirt', 2: 'grey shirt', 3: 'black shirt'}
# obb: None
# orig_img: array([[[197, 189, 195],
#         [199, 190, 197],
#         [200, 190, 198],
#         ...,
#         [126, 130, 111],
#         [124, 129, 111],
#         [127, 133, 114]],
#
#        [[197, 192, 197],
#         [197, 192, 197],
#         [196, 191, 196],
#         ...,
#         [127, 130, 111],
#         [126, 129, 111],
#         [127, 130, 112]],
#
#        [[197, 195, 199],
#         [196, 193, 198],
#         [196, 193, 198],
#         ...,
#         [127, 130, 112],
#         [126, 129, 111],
#         [126, 129, 111]],
#
#        ...,
#
#        [[ 85,  86,  86],
#         [ 79,  81,  81],
#         [ 78,  79,  79],
#         ...,
#         [138, 147, 133],
#         [136, 145, 130],
#         [135, 144, 129]],
#
#        [[ 88,  89,  89],
#         [ 85,  86,  86],
#         [ 85,  86,  86],
#         ...,
#         [128, 139, 126],
#         [131, 142, 130],
#         [131, 142, 130]],
#
#        [[ 88,  89,  89],
#         [ 87,  88,  88],
#         [ 88,  89,  89],
#         ...,
#         [136, 147, 133],
#         [133, 144, 129],
#         [131, 143, 128]]], dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: 'runs\\detect\\predict'
# speed: {'preprocess': 2.0012855529785156, 'inference': 72.95799255371094, 'postprocess': 1.0001659393310547}]
# Boxes: []
# Confidences: []
# Class IDs: []
# Frame processing time: 0.09 seconds
#
# 0: 192x256 (no detections), 67.0ms
# Speed: 2.0ms preprocess, 67.0ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 256)
# Results: [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'blue shirt', 1: 'white shirt', 2: 'grey shirt', 3: 'black shirt'}
# obb: None
# orig_img: array([[[201, 194, 199],
#         [199, 192, 197],
#         [199, 192, 197],
#         ...,
#         [126, 133, 112],
#         [123, 134, 112],
#         [123, 134, 112]],
#
#        [[199, 194, 199],
#         [198, 193, 198],
#         [197, 192, 197],
#         ...,
#         [125, 133, 114],
#         [123, 133, 114],
#         [123, 133, 114]],
#
#        [[199, 197, 202],
#         [198, 194, 200],
#         [197, 192, 199],
#         ...,
#         [123, 133, 116],
#         [121, 133, 116],
#         [122, 134, 117]],
#
#        ...,
#
#        [[ 85,  84,  84],
#         [ 89,  87,  88],
#         [ 91,  90,  90],
#         ...,
#         [142, 149, 132],
#         [143, 152, 136],
#         [132, 142, 125]],
#
#        [[ 85,  84,  84],
#         [ 85,  84,  84],
#         [ 86,  85,  85],
#         ...,
#         [139, 146, 130],
#         [137, 144, 127],
#         [124, 131, 115]],
#
#        [[ 87,  84,  82],
#         [ 88,  85,  84],
#         [ 86,  85,  85],
#         ...,
#         [139, 146, 130],
#         [142, 149, 132],
#         [128, 135, 118]]], dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: 'runs\\detect\\predict'
# speed: {'preprocess': 2.001523971557617, 'inference': 66.96009635925293, 'postprocess': 0.9992122650146484}]
# Boxes: []
# Confidences: []
# Class IDs: []
# Frame processing time: 0.08 seconds
#
# 0: 192x256 (no detections), 178.7ms
# Speed: 6.0ms preprocess, 178.7ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 256)
# Results: [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'blue shirt', 1: 'white shirt', 2: 'grey shirt', 3: 'black shirt'}
# obb: None
# orig_img: array([[[195, 191, 201],
#         [195, 191, 201],
#         [195, 191, 201],
#         ...,
#         [126, 129, 120],
#         [125, 129, 117],
#         [125, 129, 117]],
#
#        [[195, 194, 203],
#         [195, 194, 202],
#         [194, 193, 200],
#         ...,
#         [127, 130, 122],
#         [126, 130, 118],
#         [126, 130, 118]],
#
#        [[196, 198, 205],
#         [196, 197, 204],
#         [195, 194, 201],
#         ...,
#         [126, 131, 121],
#         [127, 131, 119],
#         [127, 131, 119]],
#
#        ...,
#
#        [[ 83,  77,  85],
#         [ 86,  82,  89],
#         [ 90,  87,  92],
#         ...,
#         [143, 150, 133],
#         [143, 150, 133],
#         [136, 143, 126]],
#
#        [[ 85,  80,  87],
#         [ 87,  84,  90],
#         [ 88,  85,  90],
#         ...,
#         [141, 151, 135],
#         [138, 150, 133],
#         [136, 148, 131]],
#
#        [[ 85,  82,  89],
#         [ 85,  84,  91],
#         [ 85,  85,  92],
#         ...,
#         [140, 151, 135],
#         [138, 150, 133],
#         [134, 145, 129]]], dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: 'runs\\detect\\predict'
# speed: {'preprocess': 5.996465682983398, 'inference': 178.73263359069824, 'postprocess': 0.9982585906982422}]
# Boxes: []
# Confidences: []
# Class IDs: []
# Frame processing time: 0.20 seconds
#
# 0: 192x256 (no detections), 79.0ms
# Speed: 10.0ms preprocess, 79.0ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 256)
# Results: [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'blue shirt', 1: 'white shirt', 2: 'grey shirt', 3: 'black shirt'}
# obb: None
# orig_img: array([[[193, 194, 194],
#         [191, 192, 192],
#         [190, 191, 191],
#         ...,
#         [126, 129, 120],
#         [125, 128, 119],
#         [126, 129, 120]],
#
#        [[194, 194, 196],
#         [194, 194, 196],
#         [193, 193, 195],
#         ...,
#         [127, 129, 120],
#         [126, 129, 120],
#         [126, 129, 120]],
#
#        [[200, 199, 201],
#         [199, 197, 200],
#         [196, 194, 196],
#         ...,
#         [127, 129, 120],
#         [126, 129, 120],
#         [126, 129, 120]],
#
#        ...,
#
#        [[ 90,  91,  91],
#         [ 90,  90,  90],
#         [ 92,  91,  91],
#         ...,
#         [142, 151, 139],
#         [138, 149, 137],
#         [136, 147, 135]],
#
#        [[ 91,  90,  90],
#         [ 90,  89,  89],
#         [ 90,  89,  89],
#         ...,
#         [142, 150, 137],
#         [138, 147, 133],
#         [136, 145, 130]],
#
#        [[ 90,  89,  89],
#         [ 90,  88,  86],
#         [ 91,  88,  86],
#         ...,
#         [140, 149, 135],
#         [139, 148, 134],
#         [137, 146, 132]]], dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: 'runs\\detect\\predict'
# speed: {'preprocess': 9.9945068359375, 'inference': 78.95278930664062, 'postprocess': 0.9987354278564453}]
# Boxes: []
# Confidences: []
# Class IDs: []
# Frame processing time: 0.10 seconds
#
# 0: 192x256 (no detections), 65.0ms
# Speed: 1.0ms preprocess, 65.0ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 256)
# Results: [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'blue shirt', 1: 'white shirt', 2: 'grey shirt', 3: 'black shirt'}
# obb: None
# orig_img: array([[[195, 197, 204],
#         [193, 194, 201],
#         [192, 193, 200],
#         ...,
#         [125, 130, 116],
#         [126, 130, 116],
#         [124, 128, 114]],
#
#        [[195, 197, 204],
#         [193, 194, 201],
#         [192, 193, 200],
#         ...,
#         [126, 131, 118],
#         [126, 130, 118],
#         [127, 131, 120]],
#
#        [[197, 197, 202],
#         [194, 193, 199],
#         [194, 193, 200],
#         ...,
#         [125, 130, 118],
#         [127, 131, 119],
#         [129, 132, 121]],
#
#        ...,
#
#        [[ 92,  88,  89],
#         [ 93,  88,  89],
#         [ 94,  88,  89],
#         ...,
#         [141, 152, 138],
#         [137, 148, 134],
#         [140, 151, 136]],
#
#        [[ 93,  87,  88],
#         [ 92,  84,  85],
#         [ 94,  86,  86],
#         ...,
#         [131, 143, 128],
#         [134, 145, 130],
#         [135, 146, 132]],
#
#        [[ 89,  83,  84],
#         [ 90,  83,  84],
#         [ 93,  84,  85],
#         ...,
#         [128, 138, 122],
#         [131, 141, 124],
#         [129, 138, 122]]], dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: 'runs\\detect\\predict'
# speed: {'preprocess': 0.9999275207519531, 'inference': 64.96286392211914, 'postprocess': 0.9984970092773438}]
# Boxes: []
# Confidences: []
# Class IDs: []
# Frame processing time: 0.08 seconds
#
# 0: 192x256 (no detections), 103.9ms
# Speed: 2.0ms preprocess, 103.9ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 256)
# Results: [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'blue shirt', 1: 'white shirt', 2: 'grey shirt', 3: 'black shirt'}
# obb: None
# orig_img: array([[[196, 195, 202],
#         [191, 191, 198],
#         [189, 188, 195],
#         ...,
#         [129, 132, 115],
#         [128, 129, 111],
#         [129, 130, 112]],
#
#        [[197, 197, 204],
#         [194, 193, 199],
#         [193, 192, 197],
#         ...,
#         [127, 131, 116],
#         [126, 128, 112],
#         [126, 128, 112]],
#
#        [[197, 197, 204],
#         [196, 196, 202],
#         [195, 195, 199],
#         ...,
#         [127, 132, 117],
#         [125, 129, 115],
#         [124, 128, 114]],
#
#        ...,
#
#        [[ 86,  85,  85],
#         [ 85,  84,  84],
#         [ 86,  85,  85],
#         ...,
#         [136, 144, 131],
#         [134, 142, 130],
#         [131, 140, 128]],
#
#        [[ 85,  84,  84],
#         [ 86,  84,  84],
#         [ 90,  86,  86],
#         ...,
#         [137, 145, 130],
#         [136, 142, 128],
#         [134, 140, 126]],
#
#        [[ 86,  83,  83],
#         [ 88,  84,  83],
#         [ 92,  86,  85],
#         ...,
#         [139, 146, 132],
#         [137, 143, 129],
#         [133, 140, 126]]], dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: 'runs\\detect\\predict'
# speed: {'preprocess': 1.9996166229248047, 'inference': 103.93929481506348, 'postprocess': 1.9974708557128906}]
# Boxes: []
# Confidences: []
# Class IDs: []
# Frame processing time: 0.12 seconds
#
# 0: 192x256 (no detections), 94.4ms
# Speed: 2.0ms preprocess, 94.4ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 256)
# Results: [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'blue shirt', 1: 'white shirt', 2: 'grey shirt', 3: 'black shirt'}
# obb: None
# orig_img: array([[[194, 193, 200],
#         [193, 192, 198],
#         [193, 192, 197],
#         ...,
#         [125, 128, 113],
#         [125, 129, 115],
#         [124, 128, 114]],
#
#        [[194, 193, 200],
#         [191, 191, 197],
#         [193, 192, 197],
#         ...,
#         [127, 129, 115],
#         [128, 130, 116],
#         [128, 130, 116]],
#
#        [[195, 195, 199],
#         [193, 192, 197],
#         [191, 191, 196],
#         ...,
#         [128, 130, 116],
#         [129, 131, 118],
#         [131, 132, 119]],
#
#        ...,
#
#        [[ 89,  87,  88],
#         [ 89,  86,  86],
#         [ 91,  87,  88],
#         ...,
#         [140, 148, 136],
#         [137, 145, 133],
#         [135, 143, 131]],
#
#        [[ 85,  85,  81],
#         [ 87,  86,  82],
#         [ 90,  87,  85],
#         ...,
#         [139, 145, 133],
#         [138, 144, 132],
#         [136, 142, 130]],
#
#        [[ 85,  83,  76],
#         [ 86,  84,  78],
#         [ 88,  86,  82],
#         ...,
#         [138, 144, 132],
#         [136, 142, 130],
#         [131, 137, 125]]], dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: 'runs\\detect\\predict'
# speed: {'preprocess': 1.9998550415039062, 'inference': 94.42877769470215, 'postprocess': 1.9981861114501953}]
# Boxes: []
# Confidences: []
# Class IDs: []
# Frame processing time: 0.11 seconds
#
# 0: 192x256 (no detections), 77.0ms
# Speed: 31.0ms preprocess, 77.0ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 256)
# Results: [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'blue shirt', 1: 'white shirt', 2: 'grey shirt', 3: 'black shirt'}
# obb: None
# orig_img: array([[[194, 195, 195],
#         [193, 193, 194],
#         [191, 192, 194],
#         ...,
#         [122, 118, 105],
#         [129, 125, 107],
#         [132, 128, 110]],
#
#        [[193, 196, 196],
#         [193, 195, 195],
#         [191, 192, 194],
#         ...,
#         [128, 126, 113],
#         [128, 126, 110],
#         [130, 128, 112]],
#
#        [[195, 197, 202],
#         [195, 196, 201],
#         [195, 195, 199],
#         ...,
#         [131, 130, 117],
#         [127, 126, 113],
#         [128, 128, 114]],
#
#        ...,
#
#        [[ 85,  86,  86],
#         [ 86,  86,  87],
#         [ 88,  86,  86],
#         ...,
#         [138, 148, 136],
#         [135, 143, 131],
#         [131, 140, 128]],
#
#        [[ 88,  87,  85],
#         [ 88,  87,  85],
#         [ 88,  85,  83],
#         ...,
#         [137, 145, 133],
#         [135, 143, 131],
#         [134, 142, 130]],
#
#        [[ 87,  85,  81],
#         [ 89,  86,  82],
#         [ 89,  85,  81],
#         ...,
#         [138, 146, 135],
#         [136, 144, 132],
#         [136, 144, 132]]], dtype=uint8)
# ...
#         [167, 168, 157],
#         [168, 169, 158],
#         [169, 170, 159]],
#
#        [[ 52,  56,  64],
#         [ 57,  59,  69],
#         [ 58,  58,  70],
#         ...,
#         [167, 168, 157],
#         [168, 169, 158],
#         [170, 172, 160]],
#
#        ...,
#
#        [[108, 102, 105],
#         [151, 149, 150],
#         [133, 134, 134],
#         ...,
#         [ 24,  21,  21],
#         [ 24,  21,  21],
#         [ 24,  21,  21]],
#
#        [[121, 115, 116],
#         [144, 142, 142],
#         [138, 139, 139],
#         ...,
#         [ 23,  20,  20],
#         [ 23,  20,  20],
#         [ 22,  18,  19]],
#
#        [[137, 131, 132],
#         [148, 144, 145],
#         [161, 160, 160],
#         ...,
#         [ 23,  20,  20],
#         [ 22,  18,  19],
#         [ 21,  17,  18]]], dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: 'runs\\detect\\predict'
# speed: {'preprocess': 1.9984245300292969, 'inference': 73.95696640014648, 'postprocess': 0.0}]
# Boxes: []
# Confidences: []
# Class IDs: []
# Frame processing time: 0.08 seconds
#
# 0: 192x256 (no detections), 75.0ms
# Speed: 2.0ms preprocess, 75.0ms inference, 0.2ms postprocess per image at shape (1, 3, 192, 256)
# Results: [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'blue shirt', 1: 'white shirt', 2: 'grey shirt', 3: 'black shirt'}
# obb: None
# orig_img: array([[[ 52,  51,  58],
#         [ 52,  51,  57],
#         [ 56,  56,  61],
#         ...,
#         [166, 167, 154],
#         [164, 166, 153],
#         [170, 172, 158]],
#
#        [[ 54,  54,  59],
#         [ 55,  55,  60],
#         [ 56,  56,  61],
#         ...,
#         [167, 169, 155],
#         [166, 167, 154],
#         [170, 172, 158]],
#
#        [[ 56,  56,  61],
#         [ 59,  59,  63],
#         [ 59,  59,  63],
#         ...,
#         [168, 170, 156],
#         [168, 170, 156],
#         [170, 172, 158]],
#
#        ...,
#
#        [[127, 122, 129],
#         [147, 144, 149],
#         [125, 125, 128],
#         ...,
#         [ 74,  89, 119],
#         [ 75,  90, 118],
#         [ 74,  88, 117]],
#
#        [[125, 119, 127],
#         [136, 134, 139],
#         [135, 136, 138],
#         ...,
#         [ 71,  89, 117],
#         [ 71,  89, 117],
#         [ 69,  86, 114]],
#
#        [[127, 121, 131],
#         [136, 134, 139],
#         [168, 169, 169],
#         ...,
#         [ 70,  87, 116],
#         [ 69,  86, 114],
#         [ 69,  86, 114]]], dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: 'runs\\detect\\predict'
# speed: {'preprocess': 2.000570297241211, 'inference': 75.01912117004395, 'postprocess': 0.2048015594482422}]
# Boxes: []
# Confidences: []
# Class IDs: []
# Frame processing time: 0.09 seconds
#
# 0: 192x256 (no detections), 64.0ms
# Speed: 1.0ms preprocess, 64.0ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 256)
# Results: [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'blue shirt', 1: 'white shirt', 2: 'grey shirt', 3: 'black shirt'}
# obb: None
# orig_img: array([[[ 57,  58,  65],
#         [ 57,  58,  64],
#         [ 58,  60,  64],
#         ...,
#         [162, 167, 157],
#         [165, 170, 161],
#         [165, 170, 161]],
#
#        [[ 54,  56,  61],
#         [ 56,  59,  63],
#         [ 57,  61,  66],
#         ...,
#         [170, 173, 164],
#         [170, 174, 164],
#         [169, 172, 163]],
#
#        [[ 52,  54,  59],
#         [ 57,  59,  63],
#         [ 59,  61,  66],
#         ...,
#         [173, 176, 167],
#         [172, 175, 165],
#         [169, 172, 163]],
#
#        ...,
#
#        [[131, 128, 133],
#         [147, 148, 150],
#         [133, 137, 136],
#         ...,
#         [ 92, 119, 151],
#         [ 91, 119, 151],
#         [ 90, 118, 149]],
#
#        [[120, 118, 123],
#         [141, 142, 144],
#         [144, 147, 147],
#         ...,
#         [ 92, 117, 149],
#         [ 93, 119, 151],
#         [ 93, 119, 151]],
#
#        [[121, 116, 121],
#         [141, 140, 144],
#         [158, 161, 163],
#         ...,
#         [ 91, 118, 149],
#         [ 91, 119, 151],
#         [ 92, 120, 152]]], dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: 'runs\\detect\\predict'
# speed: {'preprocess': 0.9634494781494141, 'inference': 64.03565406799316, 'postprocess': 0.9987354278564453}]
# Boxes: []
# Confidences: []
# Class IDs: []
# Frame processing time: 0.07 seconds
#
# 0: 192x256 (no detections), 67.0ms
# Speed: 2.0ms preprocess, 67.0ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 256)
# Results: [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'blue shirt', 1: 'white shirt', 2: 'grey shirt', 3: 'black shirt'}
# obb: None
# orig_img: array([[[ 53,  56,  58],
#         [ 56,  59,  61],
#         [ 59,  62,  64],
#         ...,
#         [168, 172, 159],
#         [166, 169, 158],
#         [167, 171, 159]],
#
#        [[ 51,  53,  57],
#         [ 55,  57,  60],
#         [ 57,  58,  60],
#         ...,
#         [167, 171, 158],
#         [167, 171, 159],
#         [167, 171, 159]],
#
#        [[ 48,  51,  55],
#         [ 51,  52,  55],
#         [ 53,  53,  56],
#         ...,
#         [167, 171, 159],
#         [166, 169, 158],
#         [167, 171, 159]],
#
#        ...,
#
#        [[131, 127, 137],
#         [132, 132, 138],
#         [135, 137, 139],
#         ...,
#         [ 91, 118, 152],
#         [ 91, 118, 152],
#         [ 90, 117, 151]],
#
#        [[135, 132, 141],
#         [159, 158, 164],
#         [152, 155, 157],
#         ...,
#         [ 90, 118, 152],
#         [ 91, 118, 152],
#         [ 90, 117, 151]],
#
#        [[135, 134, 145],
#         [173, 173, 181],
#         [153, 155, 160],
#         ...,
#         [ 93, 122, 156],
#         [ 97, 124, 158],
#         [ 87, 114, 148]]], dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: 'runs\\detect\\predict'
# speed: {'preprocess': 2.0008087158203125, 'inference': 66.96200370788574, 'postprocess': 1.0004043579101562}]
# Boxes: []
# Confidences: []
# Class IDs: []
# Frame processing time: 0.08 seconds
#
# 0: 192x256 (no detections), 72.0ms
# Speed: 2.0ms preprocess, 72.0ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 256)
# Results: [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'blue shirt', 1: 'white shirt', 2: 'grey shirt', 3: 'black shirt'}
# obb: None
# orig_img: array([[[ 55,  55,  62],
#         [ 53,  53,  58],
#         [ 53,  53,  57],
#         ...,
#         [166, 172, 151],
#         [172, 178, 155],
#         [168, 174, 151]],
#
#        [[ 57,  57,  64],
#         [ 56,  56,  63],
#         [ 56,  56,  63],
#         ...,
#         [167, 172, 154],
#         [179, 184, 165],
#         [169, 174, 156]],
#
#        [[ 59,  58,  65],
#         [ 59,  58,  65],
#         [ 56,  56,  63],
#         ...,
#         [165, 171, 152],
#         [164, 171, 152],
#         [166, 174, 155]],
#
#        ...,
#
#        [[132, 136, 145],
#         [125, 132, 138],
#         [122, 132, 134],
#         ...,
#         [ 95, 123, 157],
#         [ 96, 126, 159],
#         [ 98, 128, 162]],
#
#        [[135, 138, 147],
#         [133, 139, 145],
#         [137, 145, 146],
#         ...,
#         [ 98, 125, 159],
#         [ 98, 125, 159],
#         [ 99, 126, 160]],
#
#        [[149, 150, 159],
#         [157, 160, 167],
#         [150, 154, 159],
#         ...,
#         [ 99, 126, 161],
#         [ 99, 126, 162],
#         [100, 127, 164]]], dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: 'runs\\detect\\predict'
# speed: {'preprocess': 1.9993782043457031, 'inference': 71.95734977722168, 'postprocess': 0.9992122650146484}]
# Boxes: []
# Confidences: []
# Class IDs: []
# Frame processing time: 0.08 seconds
#
# 0: 192x256 (no detections), 64.9ms
# Speed: 2.2ms preprocess, 64.9ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 256)
# Results: [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'blue shirt', 1: 'white shirt', 2: 'grey shirt', 3: 'black shirt'}
# obb: None
# orig_img: array([[[ 53,  54,  63],
#         [ 52,  52,  60],
#         [ 55,  55,  62],
#         ...,
#         [161, 169, 155],
#         [162, 169, 155],
#         [161, 168, 154]],
#
#        [[ 54,  55,  64],
#         [ 54,  56,  64],
#         [ 55,  57,  64],
#         ...,
#         [162, 170, 156],
#         [164, 170, 156],
#         [163, 169, 155]],
#
#        [[ 55,  57,  66],
#         [ 57,  58,  66],
#         [ 55,  57,  64],
#         ...,
#         [163, 171, 157],
#         [166, 172, 158],
#         [165, 171, 157]],
#
#        ...,
#
#        [[138, 135, 142],
#         [136, 134, 140],
#         [129, 127, 132],
#         ...,
#         [109, 135, 167],
#         [111, 136, 168],
#         [109, 135, 167]],
#
#        [[145, 141, 151],
#         [133, 130, 137],
#         [141, 139, 144],
#         ...,
#         [106, 131, 164],
#         [108, 133, 167],
#         [109, 134, 169]],
#
#        [[157, 153, 167],
#         [149, 145, 158],
#         [152, 148, 158],
#         ...,
#         [103, 129, 162],
#         [108, 133, 167],
#         [111, 136, 170]]], dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: 'runs\\detect\\predict'
# speed: {'preprocess': 2.1615028381347656, 'inference': 64.87703323364258, 'postprocess': 0.9996891021728516}]
# Boxes: []
# Confidences: []
# Class IDs: []
# Frame processing time: 0.08 seconds
#
# 0: 192x256 (no detections), 68.0ms
# Speed: 2.0ms preprocess, 68.0ms inference, 0.0ms postprocess per image at shape (1, 3, 192, 256)
# Results: [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'blue shirt', 1: 'white shirt', 2: 'grey shirt', 3: 'black shirt'}
# obb: None
# orig_img: array([[[ 57,  56,  67],
#         [ 55,  53,  65],
#         [ 55,  54,  65],
#         ...,
#         [165, 170, 158],
#         [164, 170, 158],
#         [161, 167, 155]],
#
#        [[ 54,  55,  66],
#         [ 54,  55,  65],
#         [ 54,  55,  64],
#         ...,
#         [165, 170, 158],
#         [164, 170, 158],
#         [161, 167, 155]],
#
#        [[ 53,  54,  65],
#         [ 56,  56,  66],
#         [ 54,  55,  64],
#         ...,
#         [164, 170, 158],
#         [164, 170, 158],
#         [164, 170, 158]],
#
#        ...,
#
#        [[150, 145, 151],
#         [152, 151, 154],
#         [135, 138, 138],
#         ...,
#         [104, 128, 161],
#         [104, 129, 163],
#         [105, 130, 164]],
#
#        [[139, 136, 143],
#         [142, 143, 146],
#         [137, 140, 140],
#         ...,
#         [104, 129, 163],
#         [105, 130, 164],
#         [105, 130, 164]],
#
#        [[136, 130, 140],
#         [136, 134, 140],
#         [145, 145, 148],
#         ...,
#         [104, 129, 166],
#         [104, 131, 167],
#         [101, 128, 165]]], dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: 'runs\\detect\\predict'
# speed: {'preprocess': 1.9989013671875, 'inference': 67.9779052734375, 'postprocess': 0.0}]
# Boxes: []
# Confidences: []
# Class IDs: []
# Frame processing time: 0.08 seconds
#
# 0: 192x256 (no detections), 70.0ms
# Speed: 2.0ms preprocess, 70.0ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 256)
# Results: [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'blue shirt', 1: 'white shirt', 2: 'grey shirt', 3: 'black shirt'}
# obb: None
# orig_img: array([[[ 51,  59,  60],
#         [ 43,  48,  49],
#         [ 44,  47,  47],
#         ...,
#         [164, 170, 158],
#         [159, 167, 155],
#         [160, 169, 157]],
#
#        [[ 50,  57,  61],
#         [ 47,  52,  55],
#         [ 45,  48,  50],
#         ...,
#         [161, 167, 157],
#         [160, 166, 156],
#         [161, 167, 157]],
#
#        [[ 51,  56,  60],
#         [ 48,  52,  55],
#         [ 41,  44,  46],
#         ...,
#         [158, 165, 155],
#         [157, 165, 155],
#         [160, 168, 158]],
#
#        ...,
#
#        [[129, 126, 135],
#         [131, 131, 135],
#         [144, 147, 147],
#         ...,
#         [ 96, 119, 153],
#         [ 99, 121, 156],
#         [103, 126, 160]],
#
#        [[138, 137, 144],
#         [154, 156, 159],
#         [151, 154, 154],
#         ...,
#         [ 98, 120, 155],
#         [100, 123, 157],
#         [105, 127, 162]],
#
#        [[154, 154, 159],
#         [171, 173, 176],
#         [152, 155, 155],
#         ...,
#         [ 99, 121, 156],
#         [100, 123, 157],
#         [103, 126, 160]]], dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: 'runs\\detect\\predict'
# speed: {'preprocess': 2.000570297241211, 'inference': 70.01304626464844, 'postprocess': 0.9996891021728516}]
# Boxes: []
# Confidences: []
# Class IDs: []
# Frame processing time: 0.08 seconds
#
# 0: 192x256 (no detections), 65.2ms
# Speed: 1.0ms preprocess, 65.2ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 256)
# Results: [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'blue shirt', 1: 'white shirt', 2: 'grey shirt', 3: 'black shirt'}
# obb: None
# orig_img: array([[[ 57,  67,  68],
#         [ 44,  55,  57],
#         [ 41,  53,  54],
#         ...,
#         [161, 165, 153],
#         [160, 164, 152],
#         [162, 166, 154]],
#
#        [[ 48,  58,  59],
#         [ 43,  53,  54],
#         [ 44,  54,  56],
#         ...,
#         [161, 165, 153],
#         [161, 165, 153],
#         [163, 167, 155]],
#
#        [[ 44,  51,  55],
#         [ 45,  52,  56],
#         [ 48,  55,  59],
#         ...,
#         [162, 166, 155],
#         [163, 167, 157],
#         [166, 169, 160]],
#
#        ...,
#
#        [[138, 140, 147],
#         [136, 137, 140],
#         [132, 133, 133],
#         ...,
#         [ 98, 123, 155],
#         [ 98, 123, 155],
#         [ 99, 124, 156]],
#
#        [[129, 128, 135],
#         [145, 145, 149],
#         [145, 145, 148],
#         ...,
#         [ 97, 122, 156],
#         [ 97, 122, 156],
#         [ 95, 120, 155]],
#
#        [[140, 139, 148],
#         [147, 146, 154],
#         [148, 148, 153],
#         ...,
#         [ 96, 121, 158],
#         [ 93, 120, 156],
#         [ 92, 119, 155]]], dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: 'runs\\detect\\predict'
# speed: {'preprocess': 1.0006427764892578, 'inference': 65.15121459960938, 'postprocess': 0.9965896606445312}]
# Boxes: []
# Confidences: []
# Class IDs: []
# Frame processing time: 0.07 seconds
#
# 0: 192x256 (no detections), 62.0ms
# Speed: 1.0ms preprocess, 62.0ms inference, 1.1ms postprocess per image at shape (1, 3, 192, 256)
# Results: [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'blue shirt', 1: 'white shirt', 2: 'grey shirt', 3: 'black shirt'}
# obb: None
# orig_img: array([[[ 51,  58,  64],
#         [ 50,  54,  58],
#         [ 50,  52,  54],
#         ...,
#         [158, 163, 154],
#         [158, 163, 154],
#         [160, 166, 156]],
#
#        [[ 48,  54,  60],
#         [ 48,  53,  58],
#         [ 47,  52,  56],
#         ...,
#         [158, 163, 154],
#         [158, 163, 154],
#         [159, 164, 155]],
#
#        [[ 44,  51,  57],
#         [ 45,  52,  58],
#         [ 45,  52,  58],
#         ...,
#         [157, 163, 154],
#         [158, 163, 154],
#         [159, 164, 155]],
#
#        ...,
#
#        [[129, 134, 138],
#         [128, 131, 135],
#         [126, 129, 131],
#         ...,
#         [ 97, 122, 154],
#         [ 93, 119, 151],
#         [ 94, 120, 152]],
#
#        [[128, 135, 139],
#         [142, 148, 152],
#         [141, 145, 149],
#         ...,
#         [ 94, 121, 153],
#         [ 91, 119, 151],
#         [ 92, 120, 152]],
#
#        [[135, 140, 142],
#         [157, 162, 165],
#         [143, 147, 152],
#         ...,
#         [ 92, 120, 152],
#         [ 90, 118, 149],
#         [ 90, 118, 149]]], dtype=uint8)
# orig_shape: (480, 640)
# path: 'image0.jpg'
# probs: None
# save_dir: 'runs\\detect\\predict'
# speed: {'preprocess': 0.9992122650146484, 'inference': 61.96475028991699, 'postprocess': 1.1487007141113281}]
# Boxes: []
# Confidences: []
# Class IDs: []
# Frame processing time: 0.07 seconds
